# %% [markdown]
# Bess, Lannan

# %%
# %pylab inline

x = np.linspace(0,np.pi, num=50)
plt.figure()
plt.title("Explicit Euler")
plt.plot(x*2,-np.log(1-4*.1*(np.sin(x))**2)/.1, label=".1")
plt.plot(x*2,-np.log(1-4*.2*(np.sin(x))**2)/.2, label=".2")
plt.plot(x*2,-np.log(1-4*.5*(np.sin(x))**2)/.5, label=".5")
plt.plot(x*2,-np.log(1-4*1*(np.sin(x))**2)/1, label="1")
plt.plot(x*2, (x*2)**2,"o", label="actual")
plt.ylim([0,5])
plt.legend()

plt.figure()
plt.title("Implicit Euler")
plt.plot(x*2,-np.log(1/(1+4*.1*(np.sin(x))**2))/.1, label=".1")
plt.plot(x*2,-np.log(1/(1+4*.2*(np.sin(x))**2))/.2, label=".2")
plt.plot(x*2,-np.log(1/(1+4*.5*(np.sin(x))**2))/.5, label=".5")
plt.plot(x*2,-np.log(1/(1+4*1*(np.sin(x))**2))/1, label="1")
plt.plot(x*2, (x*2)**2,"o", label="actual")
plt.ylim([0,5])
plt.legend()

plt.figure()
plt.title("Crank-Nicolson")
plt.plot(x*2,-np.log((1-2*.1*(np.sin(x))**2)/(1+2*.1*(np.sin(x))**2))/.1, label=".1" )
plt.plot(x*2,-np.log((1-2*.2*(np.sin(x))**2)/(1+2*.2*(np.sin(x))**2))/.2, label=".2")
plt.plot(x*2,-np.log((1-2*.5*(np.sin(x))**2)/(1+2*.5*(np.sin(x))**2))/.5, label=".5")
plt.plot(x*2,-np.log((1-2*1*(np.sin(x))**2)/(1+2*1*(np.sin(x))**2))/1, label="1")
plt.plot(x*2, (x*2)**2,"o", label="actual")
plt.ylim([0,5])
plt.legend()

plt.figure()
plt.title("Actual")
plt.plot(x*2, .1*(x)**2, label=".1")
plt.plot(x*2, .2*(x)**2, label=".2")
plt.plot(x*2, .5*(x)**2, label=".5")
plt.plot(x*2, 1*(x)**2, label="1")
plt.legend()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in log
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in log
